# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-5,5,100)

# %%
y=np.sqrt(10**2-x**2)

# %%
x=np.hstack([x,-x])
y=np.hstack([y,-y])

# %%
x1=np.linspace(-5,5,100)
y1=np.sqrt(5**2-x1**2)
x1=np.hstack([x1,-x1])
y1=np.hstack([y1,-y1])

# %%
plt.scatter(x,y)
plt.scatter(x1,y1)

# %%
df1=pd.DataFrame(np.vstack([y,x]).T,columns=['X1','X2'])
df1['Y']=0

# %%
df2=pd.DataFrame(np.vstack([y1,x1]).T,columns=['X1','X2'])
df2['Y']=1

# %%
df1.head()
# Out:
#          X1       X2  Y
# 0  8.660254 -5.00000  0
# 1  8.717792 -4.89899  0
# 2  8.773790 -4.79798  0
# 3  8.828277 -4.69697  0
# 4  8.881281 -4.59596  0

# %%
df2.head()
# Out:
#          X1       X2  Y
# 0  0.000000 -5.00000  1
# 1  0.999949 -4.89899  1
# 2  1.406908 -4.79798  1
# 3  1.714198 -4.69697  1
# 4  1.969049 -4.59596  1

# %%
df=df1.append(df2)
# Out:
# /tmp/ipykernel_6552/2456558213.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df1.append(df2)

# %%
x=df.iloc[:, 0:2]

# %%
y=df.Y

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=49)

# %%
from sklearn.svm import SVC
model=SVC(kernel='rbf')
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
import seaborn as sns
sns.scatterplot(x=df['X1'],y=df['X2'],hue=df['Y'],data=df)
# Out:
# <AxesSubplot: xlabel='X1', ylabel='X2'>
